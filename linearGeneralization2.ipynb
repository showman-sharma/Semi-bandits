# %% [markdown]
# <a href="https://colab.research.google.com/github/showman-sharma/Semi-bandits/blob/main/linearGeneralization2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import random
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
from tabulate import tabulate
import time

# %% [markdown]
# # Creating an adversary

# %%
#L is number of arms; n is number of allowed combinations
# v is n x L
def createActionSet(L,n):
  return np.random.binomial(1,0.5,size = (n,L))

# %%
#L is number of arms
# mus is an L x 1 vector
def pullArms(mus, sig):
  L = mus.shape[0]
  assert sig.shape[0] == L, 'mu sig Shape mismatch'
  return np.array([random.gauss(mus[i],sig[i]) for i in range(L)])

# %% [markdown]
# # FPL with Geometric Resampling

# %%
# v is n x L
# mus is L x 1
def FPL_GR(T,v,mus,sig):
  L = mus.shape[0]
  assert v.shape[1] == L, 'Shape of v mismatched mus'
  eta = math.sqrt((math.log(L)+1)/(L*T))
  m = max(np.sum(v,axis = 1))
  M = int((math.sqrt((L*T)/(math.log(L)+1)))/(m*math.e))
  least_loss = np.min(np.dot(v,mus))
  Loss = np.zeros(shape = L)
  n = v.shape[0]
  regret = np.zeros(T+1)
  for t in range(T):
    Z = np.random.exponential(eta,size = L)
    I = np.argmin(np.dot(v,Loss-Z))
    K = M*np.ones(L)
    k = 0
    for i in range(M-1):
      Zd = np.random.exponential(eta,size = L)
      In = np.argmin(np.dot(v,Loss-Zd))
      for j in range(L):
        if v[In,j] == 1 and K[j] == M:
          K[j] = i
          k += 1
          if k == sum(v[I]):
            break      
    loss = v[I]*pullArms(mus,sig)
    Loss += K*loss
    regret[t+1] = regret[t] + (sum(loss)-least_loss)
  return regret[1:]

# %%
def regrets_FPL_GR(T,v,mus,sig,n = 1000):
  regrets = np.zeros(shape=(n,T))
  for i in range(n):
    regrets[i,:] = np.array(FPL_GR(T,v,mus,sig= sig))
  return regrets

# %% [markdown]
# # Kalman Filter

# %%
# Sigma is d x d, Theta is dx1, phi is L x d, phie is d x 1 
def Kalman(Theta,Sigma, sigma, phi, loss):
  L = phi.shape[0]; d = phi.shape[1]
  Theta_new = np.reshape(Theta.copy(),(d,1))
  Sigma_new = Sigma.copy()
  
  for i in range(len(loss)):
    if loss[i]!=0:
      #print(Theta_new.shape,Sigma_new.shape)
      phie = np.reshape((phi[i,:].T).copy(),(d,1))
      C = np.dot(np.dot(phie.T,Sigma_new),phie)+sigma*sigma
      A = (np.dot(Sigma_new,phie)/C).reshape(d,1)
      B =np.dot(A,phie.T)
      #print(A.shape)
      change1 = np.dot(B,Theta_new)
      Theta_new = Theta_new - change1 + np.reshape(loss[i]*A,(d,1))
      Sigma_new = Sigma_new - np.dot(np.dot(A,phie.T),Sigma_new)
  return Theta_new, Sigma_new

# %% [markdown]
# # CombLin TS

# %%
def CLTS(T,v, mus, phi, stddev, lam = 1, sig = 1): #stddev is for arms and sig is for algorithm
  L = v.shape[1]; #Number of arms
  n = v.shape[0]  #number of allowed combinations
  d = phi.shape[1]
  assert phi.shape[0] == L, 'Phi and v dim mismatch'
  #mus = np.dot(Phi,Theta_act)
  Sigma = lam*lam*np.eye(d)
  Theta = np.zeros((d,1))
  regret = np.zeros(T+1)
  least_loss = np.min(np.dot(v,mus))

  for t in range(T):

    Theta_t = np.random.multivariate_normal(np.reshape(Theta,d),Sigma)
    P = np.dot(phi,Theta_t)
    I = np.argmin(np.dot(v,P))
    loss = v[I]*pullArms(mus,stddev)
    #print(loss.shape)
    regret[t+1] = regret[t] + (sum(loss)-least_loss)
    Theta, Sigma = Kalman(Theta,Sigma,sig,phi,loss)
  return regret[1:]

# %%
def regrets_CLTS(T, mus,stddev, phi ,v, n = 1000, lam = 1, sig = 1):
  regrets = np.zeros(shape=(n,T))
  for i in range(n):
    regrets[i,:] = np.array(CLTS(T,v, mus, phi, stddev , lam , sig ))
  return regrets

# %% [markdown]
# # CombLin UCB

# %%
def CLUCB(T,v,mus, phi, stddev, lam = 1, sig = 1, dell = -1):
  m = max(np.sum(v,axis = 1))
  L = v.shape[1]; #Number of arms
  n = v.shape[0]  #number of allowed combinations
  d = phi.shape[1]
  dell = (1/(n*m)) if dell == -1 else dell
  assert phi.shape[0] == L, 'Phi and v dim mismatch'
  c = math.sqrt(d*math.log(1+n*m*lam*lam/(d*sig*sig))-2*math.log(dell)) + d/lam
  least_loss = np.min(np.dot(v,mus))
  Sigma = lam*lam*np.eye(d)
  Theta = np.zeros((d,1))
  regret = np.zeros(T+1)
  P = np.zeros((L,1))
  for t in range(n):
    I = t
    loss = v[I]*pullArms(mus,stddev)
    regret[t+1] = regret[t] + (sum(loss)-least_loss)
    Theta, Sigma = Kalman(Theta,Sigma,sig,phi,loss)
  for t in range(n,T):
    #for i in range(L):
      #phie = phi[i,:].T
      #P[i,0] =   np.inner(phie,Theta.T) - c*math.sqrt(np.dot(np.dot(phie.T,Sigma),phie))
    A = np.dot(phi,Sigma)
    B = A*A
    P = np.dot(phi,Theta)- np.reshape(c*np.sum(B,axis=1),(L,1))
    I = np.argmin(np.dot(v,P))
    loss = v[I]*pullArms(mus,stddev)
    regret[t+1] = regret[t] + (sum(loss)-least_loss)
    Theta, Sigma = Kalman(Theta,Sigma,sig,phi,loss)
  return regret[1:]

# %%
def regrets_CLUCB(T, mus,stddev ,phi,v, n = 1000, lam = 1, sig = 1,dell = -1):
  regrets = np.zeros(shape=(n,T))
  for i in range(n):
    regrets[i,:] = np.array(CLUCB(T,v,mus, phi, stddev, lam, sig, dell))
  return regrets

# %% [markdown]
# # Coherent Learning Case

# %% [markdown]
# ## Adversary 2:
# T = 1000,
# L = 1000,
# n = 30,
# d = 10

# %%
T2 = 1000
L2 = 1000
n2 = 30
d2 = 10
Phi2 = np.random.normal(0,5,size = (L2,d2))
Theta2 = np.random.rand(d2,1)
mus2 = np.reshape(np.dot(Phi2,Theta2),L2)
sig2 = np.ones(L2)
v2 = createActionSet(L2,n2)

# %%
s = time.time()
reg_FPL_GR2 = regrets_FPL_GR(T,v2,mus2,sig2,n=10)
e = time.time()
runtimeFPLGR = e-s
print('runtime FPL with GR = ',runtimeFPLGR)
# Out:
# runtime FPL with GR =  25.532267808914185

# %%
regret_exp_FPL_GR2 = np.mean(reg_FPL_GR2,axis = 0)
regret_std_FPL_GR2 = np.std(reg_FPL_GR2,axis = 0)

# %%
plt.figure(3,figsize = (10,10));
plt.plot([i+1 for i in range(T)],regret_exp_FPL_GR2,label = 'expected value',color = 'b');
plt.fill_between([i+1 for i in range(T)],regret_exp_FPL_GR2-regret_std_FPL_GR2,regret_exp_FPL_GR2+regret_std_FPL_GR2,color = 'r', label = 'stddev',alpha = 0.1)
plt.xlabel('$t$',fontsize = 20);
plt.ylabel('regret',fontsize = 20);
plt.title('FPL with GR: regret for L=1000,n=30',fontsize = 20,y=-0.15);
plt.legend();

# %%
s = time.time()
reg_CLTS2 = regrets_CLTS(T,mus2,sig2,Phi2,v2,n=10)
e = time.time()
runtimeCLTS = e-s
print('runtime CLTS = ',runtimeCLTS)
# Out:
# runtime CLTS =  217.71200799942017

# %%
regret_exp_CLTS2 = np.mean(reg_CLTS2,axis = 0)
regret_std_CLTS2= np.std(reg_CLTS2,axis = 0)

# %%
plt.figure(4,figsize = (10,10));
plt.plot([i+1 for i in range(T)],regret_exp_CLTS2,label = 'expected value',color = 'b');
plt.fill_between([i+1 for i in range(T)],regret_exp_CLTS2-regret_std_CLTS2,regret_exp_CLTS2+regret_std_CLTS2,color = 'r', label = 'stddev',alpha = 0.1)
plt.xlabel('$t$',fontsize = 20);
plt.ylabel('regret',fontsize = 20);
plt.title('ComblinTS:regret for L=1000,n=30',fontsize = 20,y=-0.2);
plt.legend();

# %%
s = time.time()
reg_CLUCB2 = regrets_CLUCB(T,mus2,sig2,Phi2,v2,n=10)
e = time.time()
runtimeCLUCB = e-s
print('runtime CLUCB = ',runtimeCLUCB)
# Out:
# runtime CLUCB =  215.0510013103485

# %%
regret_exp_CLUCB2 = np.mean(reg_CLUCB2,axis = 0)
regret_std_CLUCB2= np.std(reg_CLUCB2,axis = 0)

# %%
plt.figure(5,figsize = (10,10));
plt.plot([i+1 for i in range(T)],regret_exp_CLUCB2,label = 'expected value',color = 'b');
plt.fill_between([i+1 for i in range(T)],regret_exp_CLUCB2-regret_std_CLUCB2,regret_exp_CLUCB2+regret_std_CLUCB2,color = 'r', label = 'stddev',alpha = 0.1)
plt.xlabel('$t$',fontsize = 20);
plt.ylabel('regret',fontsize = 20);
plt.title('ComblinUCB:regret for L=1000,n=30',fontsize = 20);
plt.legend();

# %%
avgRT_FPLGR = runtimeFPLGR/10
avgRT_CLTS = runtimeCLTS/10
avgRT_CLUCB = runtimeCLUCB/10

# %%
rt = [['FPL with GR',avgRT_FPLGR],['CombLin TS',avgRT_CLTS],['CombLin UCB',avgRT_CLUCB]]
tableRT = tabulate(rt, headers=['Algorithm','Average RT (sec)'], tablefmt='orgtbl')
print(tableRT)
# Out:
# | Algorithm   |   Average RT (sec) |
# |-------------+--------------------|
# | FPL with GR |            2.58338 |
# | CombLin TS  |           21.7712  |
# | CombLin UCB |           21.5051  |
